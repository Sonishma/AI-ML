# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image
# display image in colab
image_grayed = Image . open ("/content/drive/MyDrive/AI ML/Data/cameraman.png")
image_gif = Image . open ("/content/drive/MyDrive/AI ML/Data/lena_gray.gif")
image_colored = Image . open ("/content/drive/MyDrive/AI ML/Data/download (5).jpg")

display ( image_grayed )
print ( " Image Format : " , image_grayed . format )
print ( " Image Size : " , image_grayed . size )
print ( " Image Mode : " , image_grayed . mode )
display ( image_gif )
print ( " Image Format : " , image_gif . format )
print ( " Image Size : " , image_gif . size )
print ( " Image Mode : " , image_gif . mode )
display ( image_colored )
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x512>
#  Image Format :  PNG
#  Image Size :  (512, 512)
#  Image Mode :  L
# <PIL.GifImagePlugin.GifImageFile image mode=P size=512x512>
#  Image Format :  GIF
#  Image Size :  (512, 512)
#  Image Mode :  P
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x414>

# %%
width , height = image_grayed . size
channels = len( image_grayed . getbands () )
print ( f" Image shape (RGB): ({ height } , { width } , { channels})")
image_size_grayed = width * height *1
print ( f" Image size (RGB): { image_size_grayed }")

width , height = image_gif .size
channels = len( image_gif . getbands () )
print ( f" Image shape (RGB): ({ height } , { width } , { channels})")
image_size_gif = width * height *1
print ( f" Image size (RGB): { image_size_gif }")

width , height = image_colored .size
channels = len( image_colored . getbands () )
print ( f" Image shape (RGB): ({ height } , { width } , { channels})")
image_size_colored = width * height *1
print ( f" Image size (RGB): { image_size_colored }")
# Out:
#  Image shape (RGB): (512 , 512 , 1)
#  Image size (RGB): 262144
#  Image shape (RGB): (512 , 512 , 1)
#  Image size (RGB): 262144
#  Image shape (RGB): (414 , 736 , 3)
#  Image size (RGB): 304704

# %%
from re import I
image_array_grayed = np . array ( image_grayed )
print (" Shape of the image array :", image_array_grayed . shape )

image_array_gif = np . array ( image_gif )
print (" Shape of the image array :", image_array_grayed . shape )

image_array_colored = np . array ( image_colored )
print (" Shape of the image array :", image_array_colored . shape )
# Out:
#  Shape of the image array : (512, 512)
#  Shape of the image array : (512, 512)
#  Shape of the image array : (414, 736, 3)

# %%
image_array_colored = np . array ( image_colored )
print (" Shape of the image array :", image_array_colored . shape)
red_channel = image_array_colored [: , : , 0]
print ( red_channel )
display ( red_channel )
green_channel = image_array_colored [: , : , 0]
print ( green_channel )
display ( green_channel )
blue_channel = image_array_colored [: , : , 2]
print ( blue_channel )
display ( blue_channel )
# Out:
#  Shape of the image array : (414, 736, 3)
# [[95 94 93 ... 45 44 43]
#  [92 91 90 ... 44 44 43]
#  [93 91 91 ... 44 43 42]
#  ...
#  [44 45 43 ... 96 94 92]
#  [48 45 42 ... 97 96 95]
#  [48 45 42 ... 96 97 98]]
# array([[95, 94, 93, ..., 45, 44, 43],
#        [92, 91, 90, ..., 44, 44, 43],
#        [93, 91, 91, ..., 44, 43, 42],
#        ...,
#        [44, 45, 43, ..., 96, 94, 92],
#        [48, 45, 42, ..., 97, 96, 95],
#        [48, 45, 42, ..., 96, 97, 98]], dtype=uint8)
# [[95 94 93 ... 45 44 43]
#  [92 91 90 ... 44 44 43]
#  [93 91 91 ... 44 43 42]
#  ...
#  [44 45 43 ... 96 94 92]
#  [48 45 42 ... 97 96 95]
#  [48 45 42 ... 96 97 98]]
# array([[95, 94, 93, ..., 45, 44, 43],
#        [92, 91, 90, ..., 44, 44, 43],
#        [93, 91, 91, ..., 44, 43, 42],
#        ...,
#        [44, 45, 43, ..., 96, 94, 92],
#        [48, 45, 42, ..., 97, 96, 95],
#        [48, 45, 42, ..., 96, 97, 98]], dtype=uint8)
# [[27 26 25 ...  6  5  4]
#  [24 23 22 ...  5  5  4]
#  [25 23 22 ...  5  4  3]
#  ...
#  [ 1  3  1 ... 53 51 49]
#  [ 6  4  1 ... 54 53 52]
#  [ 7  4  1 ... 53 54 55]]
# array([[27, 26, 25, ...,  6,  5,  4],
#        [24, 23, 22, ...,  5,  5,  4],
#        [25, 23, 22, ...,  5,  4,  3],
#        ...,
#        [ 1,  3,  1, ..., 53, 51, 49],
#        [ 6,  4,  1, ..., 54, 53, 52],
#        [ 7,  4,  1, ..., 53, 54, 55]], dtype=uint8)

# %%
r , g , b = image_colored . split ()
display ( r )
display ( g )
display ( b )
# Out:
# <PIL.Image.Image image mode=L size=736x414>
# <PIL.Image.Image image mode=L size=736x414>
# <PIL.Image.Image image mode=L size=736x414>

# %%
row_100 = image_array_colored [100 , : , :]
col_50 = image_array_colored [: , 50 , :]
pixel = image_array_colored [10 , 20 , :]
left = 100
upper = 50
right = 200
lower = 150
cropped_image = image_colored . crop (( left , upper , right , lower ) )
display ( cropped_image )
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
image_array_colored = np . zeros ((100 , 100 , 3) , dtype = np . uint8 )
image_from_array = Image . fromarray ( image_array_colored )
image_from_array . show ()
image_from_array . save ("output_image.jpg")

# %%
import numpy as np
import matplotlib . pyplot as plt
from PIL import Image

image = Image . open ("/content/drive/MyDrive/AI ML/Data/cameraman.png") . convert ("L")
image_array = np . array ( image )
height , width = image_array . shape

data = image_array . reshape ( height , width )
mean = np . mean ( data , axis =0)
centered_data = data - mean

cov_matrix = np . cov ( centered_data , rowvar = False )

eigenvalues , eigenvectors = np . linalg . eigh ( cov_matrix )
sorted_indices = np . argsort ( eigenvalues ) [:: -1]
eigenvalues = eigenvalues [ sorted_indices ]
eigenvectors = eigenvectors [: , sorted_indices ]

# Plot the explained variance ratio
explained_variance_ratio = eigenvalues / np .sum ( eigenvalues )
plt . plot ( np . cumsum ( explained_variance_ratio ) )
plt . title (" Cumulative Explained Variance ")
plt . xlabel (" Number of Components ")
plt . ylabel (" Cumulative Explained Variance ")
plt . grid ( True )
plt . show ()

k = 50  # Choose k principal components
components = eigenvectors [: , : k ]

# Project the data onto the principal components
compressed_data = np . dot ( centered_data , components )

# Project the data onto the principal components
compressed_data = np . dot ( centered_data , components )

# Reconstruct the image from compressed data
decompressed_data = np . dot ( compressed_data , components . T ) + mean

# %%
plt . figure ( figsize =(12 , 6) )
# Original Image
plt . subplot (1 , 3 , 1)
plt . imshow ( image_array , cmap ="gray")
plt . title (" Original Image ")
plt . axis ("off")
# Compressed Representation
plt . subplot (1 , 3 , 2)
plt . imshow ( compressed_data , cmap ="gray", aspect ="auto")
plt . title ( f" Compressed Image (k={k})")
plt . axis ("off")
# Decompressed Image
plt . subplot (1 , 3 , 3)
plt . imshow ( decompressed_data , cmap ="gray")
plt . title (" Decompressed Image ")
plt . axis ("off")
plt . tight_layout ()
plt . show ()
